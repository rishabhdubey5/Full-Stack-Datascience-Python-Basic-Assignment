# %% [markdown]
# 1.Add the current date to the text file today.txt as a string

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 10-07-2022

# %% [markdown]
# 2.Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 10-07-2022

# %% [markdown]
# 3.Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-07-10 00:00:00

# %% [markdown]
# 4.List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# .condarc
# .python_history
# 09.Python Basic Assignment_09.ipynb
# 10.Python Basic Assignment_10.ipynb
# 11.Python Basic Assignment_11.ipynb
# 12.Python Basic Assignment_12.ipynb
# 13.Python Basic Assignment_13.ipynb
# 14.Python Basic Assignment_14.ipynb
# 15.Python Basic Assignments_15.ipynb
# 15.Python Programming Assignment_15.ipynb
# 16.Python Basic Assignment_16.ipynb
# 17.Python Basic Assignment_17.ipynb
# 18.Python Basic Assignment_18.ipynb
# 19.Python Basic Assignment_19.ipynb
# 1st(Ineuron).ipynb
# 1ST.PNG
# 20.Python Basic Assignment_20.ipynb
# 21.Python Basic Assignment_21.ipynb
# 22.Python Basic Assignment_22.ipynb
# 23.Python Basic Assignment_23.ipynb
# 24.Python Basic Assignment_24.ipynb
# 25.Python Basic Assignment_25.ipynb
# 28th Feb Python Basic.ipynb
# 3rd class.ipynb
# agri.csv
# application_log.txt
# Array operations.ipynb
# books.csv
# books.db
# Come Back.ipynb
# data.json
# dice problem.ipynb
# dicionary.py.ipynb
# Digital Clock.ipynb
# digitalclock.JPG
# ...

# %% [markdown]
# 5.Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.AndroidStudio3.3',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.cufflinks',
#  '.dotnet',
#  '.eclipse',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.oracle_jre_usage',
#  '.p2',
#  '.python_history',
#  '.snippingtool++',
#  '.spyder-py3',
#  '.ueli',
#  '09.Python Basic Assignment_09.ipynb',
#  '10.Python Basic Assignment_10.ipynb',
#  '11.Python Basic Assignment_11.ipynb',
#  '12.Python Basic Assignment_12.ipynb',
#  '13.Python Basic Assignment_13.ipynb',
#  '14.Python Basic Assignment_14.ipynb',
#  '15.Python Basic Assignments_15.ipynb',
#  '15.Python Programming Assignment_15.ipynb',
#  '16.Python Basic Assignment_16.ipynb',
#  '17.Python Basic Assignment_17.ipynb',
#  '18.Python Basic Assignment_18.ipynb',
#  '19.Python Basic Assignment_19.ipynb',
#  '1st(Ineuron).ipynb',
#  '1ST.PNG',
#  '20.Python Basic Assignment_20.ipynb',
#  '21.Python Basic Assignment_21.ipynb',
# ...

# %% [markdown]
# 6.Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# Due to some unknown reason. the above did not print any results in the jupyter cell. so i copied the code to a python file. executed it and pasted the ouput here.
#
# Proc_one_Starttime -> 2022-07-10 15:43:03.386180 Proc_two_Starttime -> 2022-07-10 15:43:03.387359 Proc_two_Starttime -> 2022-07-10 15:43:03.387597 Proc_one_Endtime -> 2022-07-10 15:43:04.388439 Proc_two_Endtime -> 2022-07-10 15:43:04.389110 Proc_two_Endtime -> 2022-07-10 15:43:07.390314

# %% [markdown]
# 7.Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('22/05/1997','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1997-05-22 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# 8.What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1997,5,22)
my_dob.strftime("%A")
# Out:
# 'Thursday'

# %% [markdown]
# 9.When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("22/05/1997",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1970, 1, 4, 0, 0)
